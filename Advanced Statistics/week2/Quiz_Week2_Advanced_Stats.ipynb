# %%
# Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_excel("Sales_Data_1.xlsx")
df
# Out:
#              Order ID Order Date        Customer Name        City  \
# 0     BN-2011-7407039 2013-01-01           Ruby Patel   Stockholm
# 1     AZ-2011-9050313 2013-01-03       Summer Hayward   Southport
# 2     AZ-2011-6674300 2013-01-04     Devin Huddleston     Valence
# 3     BN-2011-2819714 2013-01-04          Mary Parker  Birmingham
# 4      AZ-2011-617423 2013-01-05         Daniel Burke  Echirolles
# ...               ...        ...                  ...         ...
# 4112  AZ-2014-8174835 2016-12-31         Eloise Sykes   Bielefeld
# 4113   AZ-2014-766953 2016-12-31         Jose Gambino  Maidenhead
# 4114  AZ-2014-1412225 2016-12-31          Leon Barnes   Worcester
# 4115  AZ-2014-7604524 2016-12-31  Rebecca Chamberlain     Hamburg
# 4116  BN-2014-4140795 2016-12-31      Daniel Hamilton   Eindhoven
#
#              Country   Region      Segment  Ship Date     Ship Mode  \
# 0             Sweden    North  Home Office 2013-01-05  Economy Plus
# ...

# %%
df.Year.max()
# Out:
# 2016

# %%
df[df.Profit ==df.Profit.max()]
# Out:
#             Order ID Order Date   Customer Name  City Country Region  \
# 452  AZ-2011-5313166 2013-09-08  Alexander Bond  Lugo   Spain  South
#
#        Segment  Ship Date     Ship Mode    State  \
# 452  Corporate 2013-09-11  Economy Plus  Galicia
#
#                      Product Name  Discount  Sales  Profit  Quantity  \
# 452  Hamilton Beach Stove, Silver       0.0   6517    2476        12
#
#             Category Sub-Category  Month  Year
# 452  Office Supplies   Appliances      9  2013

# %%
df.groupby("Customer Name")["Profit"].sum().sort_values()
# Out:
# Customer Name
# Melody Nelson       -3817
# Annabelle Heydon    -1927
# Leroy Samson        -1878
# David To            -1822
# Gregory Rodriguez   -1547
#                      ...
# George Dawson        2014
# Maya O'Sullivan      2041
# Lara Stoate          2044
# Harrison Cooke       2372
# Alexander Bond       2658
# Name: Profit, Length: 792, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4117 entries, 0 to 4116
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       4117 non-null   object
#  1   Order Date     4117 non-null   datetime64[ns]
#  2   Customer Name  4117 non-null   object
#  3   City           4117 non-null   object
#  4   Country        4117 non-null   object
#  5   Region         4117 non-null   object
#  6   Segment        4117 non-null   object
#  7   Ship Date      4117 non-null   datetime64[ns]
#  8   Ship Mode      4117 non-null   object
#  9   State          4117 non-null   object
#  10  Product Name   4117 non-null   object
#  11  Discount       4117 non-null   float64
#  12  Sales          4117 non-null   int64
#  13  Profit         4117 non-null   int64
#  14  Quantity       4117 non-null   int64
#  15  Category       4117 non-null   object
#  16  Sub-Category   4117 non-null   object
# ...

# %%
(df[df["Ship Mode"]=="Economy"]["Ship Date"] - df[df["Ship Mode"]=="Economy"]["Order Date"]).sum()/len(df[df["Ship Mode"]=="Economy"])
# Out:
# Timedelta('5 days 00:18:50.797546012')

# %%
df
# Out:
#              Order ID Order Date        Customer Name        City  \
# 0     BN-2011-7407039 2013-01-01           Ruby Patel   Stockholm
# 1     AZ-2011-9050313 2013-01-03       Summer Hayward   Southport
# 2     AZ-2011-6674300 2013-01-04     Devin Huddleston     Valence
# 3     BN-2011-2819714 2013-01-04          Mary Parker  Birmingham
# 4      AZ-2011-617423 2013-01-05         Daniel Burke  Echirolles
# ...               ...        ...                  ...         ...
# 4112  AZ-2014-8174835 2016-12-31         Eloise Sykes   Bielefeld
# 4113   AZ-2014-766953 2016-12-31         Jose Gambino  Maidenhead
# 4114  AZ-2014-1412225 2016-12-31          Leon Barnes   Worcester
# 4115  AZ-2014-7604524 2016-12-31  Rebecca Chamberlain     Hamburg
# 4116  BN-2014-4140795 2016-12-31      Daniel Hamilton   Eindhoven
#
#              Country   Region      Segment  Ship Date     Ship Mode  \
# 0             Sweden    North  Home Office 2013-01-05  Economy Plus
# ...

# %%
df_france = df[df["Country"]=="France"]

# %%
df_france.groupby("City")["Profit"].sum().sort_values().tail()
# Out:
# City
# Mulhouse     1537
# Nice         1948
# Marseille    1996
# Muret        2083
# Paris        4472
# Name: Profit, dtype: int64

# %%
 df[df["Category"]=="Office Supplies"]["Sub-Category"].mode()
# Out:
# 0    Art
# dtype: object

# %%
df.groupby("Product Name")["Profit"].sum().sort_values().tail()
# Out:
# Product Name
# Cisco Smart Phone, with Caller ID          3781
# SAFCO Executive Leather Armchair, Black    4076
# Safco Classic Bookcase, Metal              4183
# Nokia Smart Phone, Full Size               4782
# Hamilton Beach Stove, Silver               5778
# Name: Profit, dtype: int64

# %%
df[df["Country"]=="United Kingdom"].groupby("Category")["Sales"].sum()
# Out:
# Category
# Furniture          97154
# Office Supplies    84138
# Technology         55630
# Name: Sales, dtype: int64

# %%
df[df["Sub-Category"]=="Phones"][["Product Name","Profit"]].sort_values(by="Profit").tail()
# Out:
#                            Product Name  Profit
# 1433       Nokia Smart Phone, Full Size    1094
# 1168  Cisco Smart Phone, with Caller ID    1112
# 3330  Cisco Smart Phone, with Caller ID    1151
# 596   Cisco Smart Phone, with Caller ID    1518
# 1022       Nokia Smart Phone, Full Size    2461
