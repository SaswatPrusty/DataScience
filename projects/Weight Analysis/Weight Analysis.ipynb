# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_vangu = pd.read_csv("Shivangi Gambhir - Export Data 6-7-2020 _ 6-4-2021.csv")
df_vangu
# Out:
#                   Time    Weight   BMI Body Fat Fat-Free Body Weight  \
# 0     6/4/2021 7:35 AM  63.70 kg  25.2   27.8 %             46.00 kg
# 1    5/27/2021 6:52 AM  64.30 kg  25.4   28.2 %             46.20 kg
# 2    4/29/2021 7:19 AM  63.25 kg  25.0   27.6 %             45.80 kg
# 3    4/24/2021 6:10 AM  63.50 kg  25.1       --                   --
# 4    4/19/2021 6:56 AM  62.95 kg  24.9   27.4 %             45.70 kg
# ..                 ...       ...   ...      ...                  ...
# 112  6/20/2020 6:28 AM  70.05 kg  27.7   31.7 %             47.90 kg
# 113  6/13/2020 5:56 AM  71.90 kg  28.4   32.7 %             48.40 kg
# 114   6/7/2020 6:06 PM  72.45 kg  28.7   33.0 %             48.50 kg
# 115   6/7/2020 6:05 PM  72.75 kg  28.8   33.2 %             48.60 kg
# 116   6/7/2020 6:05 PM  74.15 kg  29.3   34.1 %             48.90 kg
#
#     Subcutaneous Fat Visceral Fat Body Water Muscle Mass Skeletal Muscles  \
# ...

# %%
df_vangu.dropna(inplace=True, axis = 0)

# %%
df_vangu.isnull().sum()
# Out:
# Time                    0
# Weight                  0
# BMI                     0
# Body Fat                0
# Fat-Free Body Weight    0
# Subcutaneous Fat        0
# Visceral Fat            0
# Body Water              0
# Muscle Mass             0
# Skeletal Muscles        0
# Bone Mass               0
# Protein                 0
# BMR                     0
# Metabolic Age           0
# dtype: int64

# %%
df_vangu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117 entries, 0 to 116
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Time                  117 non-null    object
#  1   Weight                117 non-null    object
#  2   BMI                   117 non-null    float64
#  3   Body Fat              117 non-null    object
#  4   Fat-Free Body Weight  117 non-null    object
#  5   Subcutaneous Fat      117 non-null    object
#  6   Visceral Fat          117 non-null    object
#  7   Body Water            117 non-null    object
#  8   Muscle Mass           117 non-null    object
#  9   Skeletal Muscles      117 non-null    object
#  10  Bone Mass             117 non-null    object
#  11  Protein               117 non-null    object
#  12  BMR                   117 non-null    object
#  13  Metabolic Age         117 non-null    object
# dtypes: float64(1), object(13)
# memory usage: 13.7+ KB

# %%
df_vangu.Time = pd.to_datetime(df_vangu.Time)

# %%
df_vangu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117 entries, 0 to 116
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Time                  117 non-null    datetime64[ns]
#  1   Weight                117 non-null    object
#  2   BMI                   117 non-null    float64
#  3   Body Fat              117 non-null    object
#  4   Fat-Free Body Weight  117 non-null    object
#  5   Subcutaneous Fat      117 non-null    object
#  6   Visceral Fat          117 non-null    object
#  7   Body Water            117 non-null    object
#  8   Muscle Mass           117 non-null    object
#  9   Skeletal Muscles      117 non-null    object
#  10  Bone Mass             117 non-null    object
#  11  Protein               117 non-null    object
#  12  BMR                   117 non-null    object
#  13  Metabolic Age         117 non-null    object
# ...

# %%
df_vangu.Time.duplicated().sum()
# Out:
# 12

# %%
df_vangu.drop_duplicates(inplace = True)

# %%
df_vangu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 109 entries, 0 to 116
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Time                  109 non-null    datetime64[ns]
#  1   Weight                109 non-null    object
#  2   BMI                   109 non-null    float64
#  3   Body Fat              109 non-null    object
#  4   Fat-Free Body Weight  109 non-null    object
#  5   Subcutaneous Fat      109 non-null    object
#  6   Visceral Fat          109 non-null    object
#  7   Body Water            109 non-null    object
#  8   Muscle Mass           109 non-null    object
#  9   Skeletal Muscles      109 non-null    object
#  10  Bone Mass             109 non-null    object
#  11  Protein               109 non-null    object
#  12  BMR                   109 non-null    object
#  13  Metabolic Age         109 non-null    object
# ...

# %%
df_vangu[df_vangu["Body Fat"] == "--"]
# Out:
#                    Time    Weight   BMI Body Fat Fat-Free Body Weight  \
# 3   2021-04-24 06:10:00  63.50 kg  25.1       --                   --
# 11  2020-12-11 09:45:00  64.20 kg  25.4       --                   --
# 12  2020-12-10 23:41:00  64.35 kg  25.5       --                   --
# 13  2020-12-08 18:13:00  65.80 kg  26.0       --                   --
# 19  2020-11-02 03:38:00  64.05 kg  25.3       --                   --
# ..                  ...       ...   ...      ...                  ...
# 103 2020-07-11 06:07:00  68.60 kg  27.1       --                   --
# 105 2020-07-11 06:06:00  68.85 kg  27.2       --                   --
# 106 2020-07-11 06:05:00  68.55 kg  27.1       --                   --
# 107 2020-07-10 08:55:00  68.55 kg  27.1       --                   --
# 108 2020-07-10 08:54:00  68.55 kg  27.1       --                   --
#
#     Subcutaneous Fat Visceral Fat Body Water Muscle Mass Skeletal Muscles  \
# ...

# %%
df_vangu.Weight.astype(str).str[:-2]
# Out:
# 0      63.70
# 1      64.30
# 2      63.25
# 3      63.50
# 4      62.95
#         ...
# 112    70.05
# 113    71.90
# 114    72.45
# 115    72.75
# 116    74.15
# Name: Weight, Length: 109, dtype: object

# %%
df_vangu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 109 entries, 0 to 116
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Time                  109 non-null    datetime64[ns]
#  1   Weight                109 non-null    float64
#  2   BMI                   109 non-null    float64
#  3   Body Fat              109 non-null    object
#  4   Fat-Free Body Weight  109 non-null    object
#  5   Subcutaneous Fat      109 non-null    object
#  6   Visceral Fat          109 non-null    object
#  7   Body Water            109 non-null    object
#  8   Muscle Mass           109 non-null    object
#  9   Skeletal Muscles      109 non-null    object
#  10  Bone Mass             109 non-null    object
#  11  Protein               109 non-null    object
#  12  BMR                   109 non-null    object
#  13  Metabolic Age         109 non-null    object
# ...

# %%
df_vangu.Time.duplicated().sum()
# Out:
# 4

# %%
df_vangu.drop_duplicates(inplace=True)

# %%
df_vangu.Time.duplicated().sum()
# Out:
# 4

# %%
df_vangu.drop_duplicates(subset=None, keep="first", inplace=True)

# %%
df_vangu.Time.duplicated().sum()
# Out:
# 4

# %%
df = df_vangu[df_vangu.Time.duplicated() == False]

# %%
df.sort_values(by =df.Time, ascending = True )

# %%
df.Time.duplicated().sum()

# %%
df.sort_values(by = "Time", ascending = True, inplace = True)
# Out:
# <ipython-input-25-3aec77bd80c0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.sort_values(by = "Time", ascending = True, inplace = True)

# %%
df.reset_index(inplace=True)

# %%
df.columns

# %%
df.drop(columns="index", axis = 1, inplace = True)

# %%
df.rename(columns = {"level_0":"Index"}, inplace = True)

# %%
df
# Out:
#                    Time  Weight   BMI Body Fat Fat-Free Body Weight  \
# 115 2020-06-07 18:05:00   72.75  28.8   33.2 %             48.60 kg
# 114 2020-06-07 18:06:00   72.45  28.7   33.0 %             48.50 kg
# 113 2020-06-13 05:56:00   71.90  28.4   32.7 %             48.40 kg
# 112 2020-06-20 06:28:00   70.05  27.7   31.7 %             47.90 kg
# 111 2020-07-04 06:37:00   69.10  27.3   31.0 %             47.60 kg
# ..                  ...     ...   ...      ...                  ...
# 4   2021-04-19 06:56:00   62.95  24.9   27.4 %             45.70 kg
# 3   2021-04-24 06:10:00   63.50  25.1       --                   --
# 2   2021-04-29 07:19:00   63.25  25.0   27.6 %             45.80 kg
# 1   2021-05-27 06:52:00   64.30  25.4   28.2 %             46.20 kg
# 0   2021-06-04 07:35:00   63.70  25.2   27.8 %             46.00 kg
#
#     Subcutaneous Fat Visceral Fat Body Water Muscle Mass Skeletal Muscles  \
# 115           29.2 %        11.0      45.8 %    45.70 kg           38.9 %
# ...

# %%
df.head(50)
# Out:
#                    Time  Weight   BMI Body Fat Fat-Free Body Weight  \
# 115 2020-06-07 18:05:00   72.75  28.8   33.2 %             48.60 kg
# 114 2020-06-07 18:06:00   72.45  28.7   33.0 %             48.50 kg
# 113 2020-06-13 05:56:00   71.90  28.4   32.7 %             48.40 kg
# 112 2020-06-20 06:28:00   70.05  27.7   31.7 %             47.90 kg
# 111 2020-07-04 06:37:00   69.10  27.3   31.0 %             47.60 kg
# 109 2020-07-04 06:40:00   68.80  27.2   30.9 %             47.60 kg
# 108 2020-07-10 08:54:00   68.55  27.1       --                   --
# 107 2020-07-10 08:55:00   68.55  27.1       --                   --
# 106 2020-07-11 06:05:00   68.55  27.1       --                   --
# 105 2020-07-11 06:06:00   68.85  27.2       --                   --
# 103 2020-07-11 06:07:00   68.60  27.1       --                   --
# 101 2020-07-11 06:08:00   68.60  27.1   30.7 %             47.50 kg
# 100 2020-07-12 15:27:00   67.60  26.7       --                   --
# ...

# %%
final_df = df[df["Body Fat"]!="--"]

# %%
final_df
# Out:
#                    Time  Weight   BMI Body Fat Fat-Free Body Weight  \
# 115 2020-06-07 18:05:00   72.75  28.8   33.2 %             48.60 kg
# 114 2020-06-07 18:06:00   72.45  28.7   33.0 %             48.50 kg
# 113 2020-06-13 05:56:00   71.90  28.4   32.7 %             48.40 kg
# 112 2020-06-20 06:28:00   70.05  27.7   31.7 %             47.90 kg
# 111 2020-07-04 06:37:00   69.10  27.3   31.0 %             47.60 kg
# 109 2020-07-04 06:40:00   68.80  27.2   30.9 %             47.60 kg
# 101 2020-07-11 06:08:00   68.60  27.1   30.7 %             47.50 kg
# 96  2020-07-17 06:11:00   67.70  26.8   30.2 %             47.20 kg
# 95  2020-07-17 06:13:00   67.65  26.8   30.2 %             47.20 kg
# 86  2020-07-25 07:18:00   67.20  26.6   29.9 %             47.10 kg
# 84  2020-07-25 07:26:00   67.05  26.5   29.8 %             47.10 kg
# 70  2020-08-03 07:17:00   66.80  26.4   29.7 %             47.00 kg
# 62  2020-08-08 07:00:00   66.00  26.1   29.2 %             46.70 kg
# ...

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39 entries, 115 to 0
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Time                  39 non-null     datetime64[ns]
#  1   Weight                39 non-null     float64
#  2   BMI                   39 non-null     float64
#  3   Body Fat              39 non-null     object
#  4   Fat-Free Body Weight  39 non-null     object
#  5   Subcutaneous Fat      39 non-null     object
#  6   Visceral Fat          39 non-null     object
#  7   Body Water            39 non-null     object
#  8   Muscle Mass           39 non-null     object
#  9   Skeletal Muscles      39 non-null     object
#  10  Bone Mass             39 non-null     object
#  11  Protein               39 non-null     object
#  12  BMR                   39 non-null     object
#  13  Metabolic Age         39 non-null     object
# ...

# %%
final_df["Fat-Free Body Weight"] = pd.to_numeric(final_df["Fat-Free Body Weight"].astype(str).str[:-2])
# Out:
# <ipython-input-34-f196486db7a4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df["Fat-Free Body Weight"] = pd.to_numeric(final_df["Fat-Free Body Weight"].astype(str).str[:-2])

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39 entries, 115 to 0
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Time                  39 non-null     datetime64[ns]
#  1   Weight                39 non-null     float64
#  2   BMI                   39 non-null     float64
#  3   Body Fat              39 non-null     object
#  4   Fat-Free Body Weight  39 non-null     float64
#  5   Subcutaneous Fat      39 non-null     object
#  6   Visceral Fat          39 non-null     object
#  7   Body Water            39 non-null     object
#  8   Muscle Mass           39 non-null     object
#  9   Skeletal Muscles      39 non-null     object
#  10  Bone Mass             39 non-null     object
#  11  Protein               39 non-null     object
#  12  BMR                   39 non-null     object
#  13  Metabolic Age         39 non-null     object
# ...

# %%
final_df["Body Fat"] = pd.to_numeric(final_df["Body Fat"].astype(str).str[:-1])
# Out:
# <ipython-input-37-afe40a70dbf1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df["Body Fat"] = pd.to_numeric(final_df["Body Fat"].astype(str).str[:-1])

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39 entries, 115 to 0
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Time                  39 non-null     datetime64[ns]
#  1   Weight                39 non-null     float64
#  2   BMI                   39 non-null     float64
#  3   Body Fat              39 non-null     float64
#  4   Fat-Free Body Weight  39 non-null     float64
#  5   Subcutaneous Fat      39 non-null     object
#  6   Visceral Fat          39 non-null     object
#  7   Body Water            39 non-null     object
#  8   Muscle Mass           39 non-null     object
#  9   Skeletal Muscles      39 non-null     object
#  10  Bone Mass             39 non-null     object
#  11  Protein               39 non-null     object
#  12  BMR                   39 non-null     object
#  13  Metabolic Age         39 non-null     object
# ...

# %%
df
# Out:
#                    Time  Weight   BMI Body Fat Fat-Free Body Weight  \
# 115 2020-06-07 18:05:00   72.75  28.8   33.2 %             48.60 kg
# 114 2020-06-07 18:06:00   72.45  28.7   33.0 %             48.50 kg
# 113 2020-06-13 05:56:00   71.90  28.4   32.7 %             48.40 kg
# 112 2020-06-20 06:28:00   70.05  27.7   31.7 %             47.90 kg
# 111 2020-07-04 06:37:00   69.10  27.3   31.0 %             47.60 kg
# ..                  ...     ...   ...      ...                  ...
# 4   2021-04-19 06:56:00   62.95  24.9   27.4 %             45.70 kg
# 3   2021-04-24 06:10:00   63.50  25.1       --                   --
# 2   2021-04-29 07:19:00   63.25  25.0   27.6 %             45.80 kg
# 1   2021-05-27 06:52:00   64.30  25.4   28.2 %             46.20 kg
# 0   2021-06-04 07:35:00   63.70  25.2   27.8 %             46.00 kg
#
#     Subcutaneous Fat Visceral Fat Body Water Muscle Mass Skeletal Muscles  \
# 115           29.2 %        11.0      45.8 %    45.70 kg           38.9 %
# ...

# %%
change_last_char_columns = {"Subcutaneous Fat", "Body Water", "Skeletal Muscles", "Protein"}
for col in change_last_char_columns:
# Out:
# <ipython-input-40-14ac4096400e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df[col] = pd.to_numeric(final_df[col].astype(str).str[:-1])

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39 entries, 115 to 0
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Time                  39 non-null     datetime64[ns]
#  1   Weight                39 non-null     float64
#  2   BMI                   39 non-null     float64
#  3   Body Fat              39 non-null     float64
#  4   Fat-Free Body Weight  39 non-null     float64
#  5   Subcutaneous Fat      39 non-null     float64
#  6   Visceral Fat          39 non-null     object
#  7   Body Water            39 non-null     float64
#  8   Muscle Mass           39 non-null     object
#  9   Skeletal Muscles      39 non-null     float64
#  10  Bone Mass             39 non-null     object
#  11  Protein               39 non-null     float64
#  12  BMR                   39 non-null     object
#  13  Metabolic Age         39 non-null     object
# ...

# %%
final_df["Visceral Fat"] = pd.to_numeric(final_df["Visceral Fat"])
# Out:
# <ipython-input-42-5bbdec982157>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df["Visceral Fat"] = pd.to_numeric(final_df["Visceral Fat"])

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39 entries, 115 to 0
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Time                  39 non-null     datetime64[ns]
#  1   Weight                39 non-null     float64
#  2   BMI                   39 non-null     float64
#  3   Body Fat              39 non-null     float64
#  4   Fat-Free Body Weight  39 non-null     float64
#  5   Subcutaneous Fat      39 non-null     float64
#  6   Visceral Fat          39 non-null     float64
#  7   Body Water            39 non-null     float64
#  8   Muscle Mass           39 non-null     object
#  9   Skeletal Muscles      39 non-null     float64
#  10  Bone Mass             39 non-null     object
#  11  Protein               39 non-null     float64
#  12  BMR                   39 non-null     object
#  13  Metabolic Age         39 non-null     object
# ...

# %%
final_df.BMR
# Out:
# 115    1419 Kcal
# 114    1418 Kcal
# 113    1415 Kcal
# 112    1403 Kcal
# 111    1399 Kcal
# 109    1396 Kcal
# 101    1396 Kcal
# 96     1390 Kcal
# 95     1389 Kcal
# 86     1387 Kcal
# 84     1386 Kcal
# 70     1384 Kcal
# 62     1379 Kcal
# 60     1378 Kcal
# 49     1382 Kcal
# 45     1377 Kcal
# 44     1377 Kcal
# 43     1377 Kcal
# 42     1375 Kcal
# 31     1374 Kcal
# 29     1365 Kcal
# 24     1369 Kcal
# 23     1361 Kcal
# 21     1362 Kcal
# 18     1369 Kcal
# 17     1359 Kcal
# 16     1360 Kcal
# 15     1359 Kcal
# 14     1356 Kcal
# 10     1362 Kcal
# 9      1354 Kcal
# 8      1361 Kcal
# 7      1356 Kcal
# 6      1370 Kcal
# 5      1362 Kcal
# 4      1357 Kcal
# 2      1359 Kcal
# 1      1367 Kcal
# 0      1363 Kcal
# Name: BMR, dtype: object

# %%
    final_df["BMR"] = pd.to_numeric(final_df["BMR"].astype(str).str[:-4])
# Out:
# <ipython-input-47-07f0845a9ae9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df["BMR"] = pd.to_numeric(final_df["BMR"].astype(str).str[:-4])

# %%
    final_df["Muscle Mass"] = pd.to_numeric(final_df["Muscle Mass"].astype(str).str[:-2])
    final_df["Bone Mass"] = pd.to_numeric(final_df["Bone Mass"].astype(str).str[:-2])
# Out:
# <ipython-input-48-7407f63fd90b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df["Muscle Mass"] = pd.to_numeric(final_df["Muscle Mass"].astype(str).str[:-2])
# <ipython-input-48-7407f63fd90b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df["Bone Mass"] = pd.to_numeric(final_df["Bone Mass"].astype(str).str[:-2])

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39 entries, 115 to 0
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Time                  39 non-null     datetime64[ns]
#  1   Weight                39 non-null     float64
#  2   BMI                   39 non-null     float64
#  3   Body Fat              39 non-null     float64
#  4   Fat-Free Body Weight  39 non-null     float64
#  5   Subcutaneous Fat      39 non-null     float64
#  6   Visceral Fat          39 non-null     float64
#  7   Body Water            39 non-null     float64
#  8   Muscle Mass           39 non-null     float64
#  9   Skeletal Muscles      39 non-null     float64
#  10  Bone Mass             39 non-null     float64
#  11  Protein               39 non-null     float64
#  12  BMR                   39 non-null     int64
#  13  Metabolic Age         39 non-null     object
# ...

# %%
final_df["Metabolic Age"] = pd.to_numeric(final_df["Metabolic Age"])
# Out:
# <ipython-input-52-c095650282ad>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df["Metabolic Age"] = pd.to_numeric(final_df["Metabolic Age"])

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39 entries, 115 to 0
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Time                  39 non-null     datetime64[ns]
#  1   Weight                39 non-null     float64
#  2   BMI                   39 non-null     float64
#  3   Body Fat              39 non-null     float64
#  4   Fat-Free Body Weight  39 non-null     float64
#  5   Subcutaneous Fat      39 non-null     float64
#  6   Visceral Fat          39 non-null     float64
#  7   Body Water            39 non-null     float64
#  8   Muscle Mass           39 non-null     float64
#  9   Skeletal Muscles      39 non-null     float64
#  10  Bone Mass             39 non-null     float64
#  11  Protein               39 non-null     float64
#  12  BMR                   39 non-null     int64
#  13  Metabolic Age         39 non-null     int64
# ...

# %%
final_df.describe()
# Out:
#           Weight        BMI   Body Fat  Fat-Free Body Weight  \
# count  39.000000  39.000000  39.000000             39.000000
# mean   65.676923  25.976923  28.958974             46.610256
# std     2.796117   1.104646   1.714906              0.823598
# min    62.450000  24.700000  25.800000             45.600000
# 25%    63.425000  25.100000  27.650000             45.900000
# 50%    65.250000  25.800000  28.700000             46.500000
# 75%    67.125000  26.550000  29.850000             47.100000
# max    72.750000  28.800000  33.200000             48.600000
#
#        Subcutaneous Fat  Visceral Fat  Body Water  Muscle Mass  \
# count         39.000000     39.000000   39.000000    39.000000
# mean          25.858974      8.051282   48.746154    43.807692
# std            1.376440      1.145902    1.187622     0.785187
# min           23.100000      7.000000   45.800000    42.800000
# 25%           24.850000      7.000000   48.150000    43.200000
# ...

# %%
sns.histplot(x = final_df.Weight)
# Out:
# <AxesSubplot:xlabel='Weight', ylabel='Count'>

# %%
sns.boxplot(x = final_df.Weight)
# Out:
# <AxesSubplot:xlabel='Weight'>

# %%
final_df.corr()
# Out:
#                         Weight       BMI  Body Fat  Fat-Free Body Weight  \
# Weight                1.000000  0.999641  0.992811              0.989315
# BMI                   0.999641  1.000000  0.992460              0.988645
# Body Fat              0.992811  0.992460  1.000000              0.966564
# Fat-Free Body Weight  0.989315  0.988645  0.966564              1.000000
# Subcutaneous Fat      0.988567  0.988315  0.999293              0.958641
# Visceral Fat          0.973236  0.973912  0.962607              0.969789
# Body Water           -0.992795 -0.992301 -0.999006             -0.966364
# Muscle Mass           0.985963  0.985361  0.960610              0.998501
# Skeletal Muscles     -0.993596 -0.993275 -0.998908             -0.968488
# Bone Mass             0.805713  0.804112  0.778427              0.830617
# Protein              -0.986064 -0.985345 -0.996182             -0.959731
# BMR                   0.988295  0.987498  0.964368              0.999025
# ...

# %%
sns.lineplot(x = final_df.Weight, y = final_df["Body Fat"])
# Out:
# <AxesSubplot:xlabel='Weight', ylabel='Body Fat'>

# %%
sns.lineplot(x = final_df.Weight, y = final_df["Muscle Mass"])
# Out:
# <AxesSubplot:xlabel='Weight', ylabel='Muscle Mass'>

# %%
sns.lineplot(x = final_df.Weight, y = final_df["Visceral Fat"])
# Out:
# <AxesSubplot:xlabel='Weight', ylabel='Visceral Fat'>

# %%
sns.lineplot(x = final_df.Weight, y = final_df["Subcutaneous Fat"])
# Out:
# <AxesSubplot:xlabel='Weight', ylabel='Subcutaneous Fat'>

# %%
sns.lineplot(x = final_df["Body Fat"], y = final_df["Subcutaneous Fat"])
# Out:
# <AxesSubplot:xlabel='Body Fat', ylabel='Subcutaneous Fat'>

# %%
sns.lineplot(x = final_df["Body Fat"], y = final_df["Visceral Fat"])
# Out:
# <AxesSubplot:xlabel='Body Fat', ylabel='Visceral Fat'>

# %%
sns.lineplot(x = final_df["Weight"], y = final_df["Fat-Free Body Weight"])
# Out:
# <AxesSubplot:xlabel='Weight', ylabel='Fat-Free Body Weight'>

# %%
plt.figure(figsize=(30,30))
sns.pairplot(final_df)

# %%
sns.lineplot(x = final_df["Weight"], y = final_df["Body Water"])
# Out:
# <AxesSubplot:xlabel='Weight', ylabel='Body Water'>

# %%
sns.lineplot(x = final_df.Time, y = final_df.Weight)
# Out:
# <AxesSubplot:xlabel='Time', ylabel='Weight'>

# %%
sns.lineplot(x = final_df.Time, y = final_df["Body Fat"])
# Out:
# <AxesSubplot:xlabel='Time', ylabel='Body Fat'>

# %%
sns.lineplot(x = final_df.Time, y = final_df["Visceral Fat"])
# Out:
# <AxesSubplot:xlabel='Time', ylabel='Visceral Fat'>

# %%
sns.lineplot(x = final_df.Time, y =final_df["Subcutaneous Fat"])
# Out:
# <AxesSubplot:xlabel='Time', ylabel='Subcutaneous Fat'>

# %%
sns.lineplot(x = final_df.Time, y = final_df["Fat-Free Body Weight"])
# Out:
# <AxesSubplot:xlabel='Time', ylabel='Fat-Free Body Weight'>

# %%
sns.lineplot(x = final_df.Protein, y = final_df.Weight)
# Out:
# <AxesSubplot:xlabel='Protein', ylabel='Weight'>

# %%
sns.lineplot(x = final_df.Time, y= final_df.Protein)
# Out:
# <AxesSubplot:xlabel='Time', ylabel='Protein'>
